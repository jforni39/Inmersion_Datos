# %%
import pandas as pd

# %%
inmuebles = pd.read_csv('/content/drive/MyDrive/inmuebles_bogota.csv')
inmuebles.head(10)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
# 5  Apartamento         Apartamento en venta en Bella Suiza             1
# 6  Apartamento         Apartamento en venta en Bella Suiza             1
# 7  Apartamento         Apartamento en venta en Bella Suiza             3
# 8  Apartamento            Apartamento en venta en El Chicó             3
# 9  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# ...

# %%
columnas={'Área':'Area'}
inmuebles = inmuebles.rename(columns= columnas)
inmuebles.sample(10)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 7916         Casa                Casa en venta en Usaquén             3
# 9142  Apartamento  Apartamento en venta en Nueva Zelandia             3
# 3109         Casa               Casa en venta en Cedritos             3
# 7943         Casa                   Casa en venta en Bosa             5
# 5896  Apartamento      Apartamento en venta en La Calleja             5
# 8958  Apartamento         Apartamento en venta en Usaquén             3
# 3183        Local        Local en venta en Barrios Unidos             1
# 3159  Apartamento            Apartamento en venta en Usme             1
# 3470  Apartamento       Apartamento en venta en Chapinero             1
# 2065  Apartamento  Apartamento en venta en Barrios Unidos             3
#
#       Baños  Area          Barrio  \
# 7916      3   129         Usaquén
# 9142      2   120  Nueva Zelandia
# 3109      4   124        Cedritos
# ...

# %% [markdown]
# Promedio de Area de todos los Barrios

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
round(146.66470588235293, 2)
# Out:
# 146.66

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Valor Maximo de la columna Valor

# %%
Valor_Maximo = inmuebles.Valor.max()
Valor_Maximo
# Out:
# '$ 999.000.000'

# %% [markdown]
# Media de dos columnas

# %%
 inmuebles[['Area','Habitaciones']].mean().round(2)
# Out:
# Area            146.66
# Habitaciones      3.07
# dtype: float64

# %% [markdown]
# Grafico de la columna Valor

# %%
inmuebles_Valor = inmuebles.Valor.value_counts()
inmuebles_Valor.head(10).plot.bar(color ='orange')
# Out:
# <Axes: >
